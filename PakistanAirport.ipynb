# %% [markdown]
# MUHAMMAD HASHIM SHAFIQUE
# F2018065202

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/AirportsOfPakistan.csv', encoding=('ISO-8859-1'))

# %%
df.head()
# Out:
#      id ident            type                                  name  \
# 0  5233  OPKV  medium_airport          Jinnah International Airport
# 1  5255  OPKC  medium_airport          Jinnah International Airport
# 2  5274  OPRN  medium_airport  Benazir Bhutto International Airport
# 3  5257  OPLA  medium_airport     Alama Iqbal International Airport
# 4  5270  OPPS  medium_airport        Peshawar International Airport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     24.906500      67.160797           100        AS          PK      PK-SD
# 1     24.906500      67.160797           100        AS          PK      PK-SD
# 2     33.616699      73.099197          1668        AS          PK      PK-PB
# 3     31.521601      74.403603           712        AS          PK      PK-PB
# 4     33.993900      71.514603          1158        AS          PK      PK-NW
#
#    ... scheduled_service  gps_code iata_code local_code home_link      \
# ...

# %%
df.tail()
# Out:
#          id    ident           type              name  latitude_deg  \
# 132  325953  PK-0024         closed  Spezand Airfield     29.916193
# 133  317905  PK-0020  small_airport   Sujawal Airport     24.614100
# 134  325944  PK-0022         closed      Tank Airport     32.198090
# 135   41644  PK-0011       heliport   Walton Heliport     31.489800
# 136  301278      ZIZ       heliport  Zamzama Heliport     26.710944
#
#      longitude_deg  elevation_ft continent iso_country iso_region  ...  \
# 132      66.987726          5790        AS          PK      PK-BA  ...
# 133      68.082700            30        AS          PK      PK-SD  ...
# 134      70.404027           825        AS          PK      PK-NW  ...
# 135      74.348801           695        AS          PK      PK-PB  ...
# 136      67.667250           128        AS          PK      PK-SD  ...
#
#     scheduled_service  gps_code iata_code local_code home_link      \
# ...

# %%
df.shape
# Out:
# (137, 21)

# %%
df.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link    ', 'wikipedia_link', 'keywords', 'score',
#        'last_updated', 'landing'],
#       dtype='object')

# %%
plt.hist(df['longitude_deg'], log=True)
plt.xlabel('longitude_deg')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['latitude_deg'], log=True)
plt.xlabel('latitude_deg')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(df['elevation_ft'], log=True)
plt.xlabel('elevation_ft')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
df.boxplot("longitude_deg", "latitude_deg")
plt.ylabel('latitude_deg')
plt.xlabel('longitude_deg')
# Out:
# Text(0.5, 0, 'longitude_deg')

# %%
df.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft  \
# count     137.000000    137.000000     137.000000    137.000000
# mean    50334.802920     29.770079      69.629504   1484.635036
# std     91703.533115      3.219495       3.315396   1775.435944
# min      5233.000000     24.614100      61.595402      3.000000
# 25%      5279.000000     27.166700      67.228000    200.000000
# 50%     30590.000000     29.653524      69.771797    620.000000
# 75%     41624.000000     32.563099      72.391670   2408.000000
# max    325955.000000     35.918800      75.536003   7316.000000
#
#        scheduled_service  home_link            score
# count         137.000000          137.0   137.000000
# mean            0.262774          321.0   226.459854
# std             0.441756            0.0   321.127472
# min             0.000000          321.0     0.000000
# 25%             0.000000          321.0    50.000000
# 50%             0.000000          321.0    50.000000
# ...

# %%
df.dtypes
# Out:
# id                     int64
# ident                 object
# type                  object
# name                  object
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft           int64
# continent             object
# iso_country           object
# iso_region            object
# municipality          object
# scheduled_service      int64
# gps_code              object
# iata_code             object
# local_code            object
# home_link              int64
# wikipedia_link        object
# keywords              object
# score                  int64
# last_updated          object
# landing               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft           0
# continent              0
# iso_country            0
# iso_region             0
# municipality           0
# scheduled_service      0
# gps_code               0
# iata_code              0
# local_code             0
# home_link              0
# wikipedia_link         0
# keywords             121
# score                  0
# last_updated           0
# landing                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 137 non-null    int64
#  1   ident              137 non-null    object
#  2   type               137 non-null    object
#  3   name               137 non-null    object
#  4   latitude_deg       137 non-null    float64
#  5   longitude_deg      137 non-null    float64
#  6   elevation_ft       137 non-null    int64
#  7   continent          137 non-null    object
#  8   iso_country        137 non-null    object
#  9   iso_region         137 non-null    object
#  10  municipality       137 non-null    object
#  11  scheduled_service  137 non-null    int64
#  12  gps_code           137 non-null    object
#  13  iata_code          137 non-null    object
#  14  local_code         137 non-null    object
#  15  home_link          137 non-null    int64
# ...

# %%
df = df.drop(['keywords'],axis=1)
df.isnull().sum()
# Out:
# id                   0
# ident                0
# type                 0
# name                 0
# latitude_deg         0
# longitude_deg        0
# elevation_ft         0
# continent            0
# iso_country          0
# iso_region           0
# municipality         0
# scheduled_service    0
# gps_code             0
# iata_code            0
# local_code           0
# home_link            0
# wikipedia_link       0
# score                0
# last_updated         0
# landing              0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **NUMPY OPERATIONS:**

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df['longitude_deg'], kde = True, color = 'c')
plt.title('Distribution of longitude_deg')
# Out:
# Text(0.5, 1.0, 'Distribution of longitude_deg')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.distplot(np.log10(df['longitude_deg']), kde = True, color = 'r' )

# %%
ax = sns.lmplot(x = 'latitude_deg', y = 'longitude_deg', data=df, hue='landing', palette='Set2')

# %%
df.memory_usage()
# Out:
# Index                 128
# id                   1096
# ident                1096
# type                 1096
# name                 1096
# latitude_deg         1096
# longitude_deg        1096
# elevation_ft         1096
# continent            1096
# iso_country          1096
# iso_region           1096
# municipality         1096
# scheduled_service    1096
# gps_code             1096
# iata_code            1096
# local_code           1096
# home_link            1096
# wikipedia_link       1096
# score                1096
# last_updated         1096
# landing              1096
# dtype: int64

# %%
df.value_counts()
# Out:
# id      ident    type            name                          latitude_deg  longitude_deg  elevation_ft  continent  iso_country  iso_region  municipality   scheduled_service  gps_code  iata_code  local_code  home_link      wikipedia_link                                              score  last_updated               landing
# 5233    OPKV     medium_airport  Jinnah International Airport  24.906500     67.160797      100           AS         PK           PK-SD       Karachi        1                  OPKC      KHI        OP1Y        321            https://en.wikipedia.org/wiki/Jinnah_International_Airport  1050   2016-05-15T18:05:15+00:01  yes        1
# 41616   OPKA     small_airport   Cape Monz Airport             24.827932     66.664429      40            AS         PK           PK-SD       Cape Monz      0                  OPKA      CWP        OP18        321            https://en.wikipedia.org/wiki/Abbottabad_Airport            50     2008-09-01T20:47:42+00:00  no         1
# ...

# %%
df.plot(kind='scatter', x='longitude_deg', y='latitude_deg', rot=10)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
x = df['longitude_deg']
y = df['latitude_deg']

# %%
fig, ax = plt.subplots(figsize = (5,5))
plt.ylabel('longitude_deg')
plt.xlabel('latitude_deg')
plt.bar(x, y)
# Out:
# <BarContainer object of 137 artists>

# %%
fig, ax = plt.subplots(figsize = (3,3))
plt.ylabel('longitude_deg')
plt.xlabel('latitude_deg')
plt.bar(x, y)
# Out:
# <BarContainer object of 137 artists>

# %%
sns.boxplot(x='elevation_ft', data =df , width = 0.5)

# %%
sns.boxplot(x='municipality', data =df , width = 0.5)

# %%
sns.boxplot(x='latitude_deg', data =df , width = 0.8)

# %% [markdown]
# **FINDING CO-RELATIONS USING SEABORN HEATMAP:**

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(12,12))
g=sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# **Linear Regression:**

# %%
df[['ident', 'type', 'name', 'continent', 'iso_country', 'iso_region', 'municipality', 'gps_code', 'iata_code', 'local_code', 'wikipedia_link', 'last_updated','landing']] = df[['ident', 'type', 'name', 'continent', 'iso_country', 'iso_region', 'municipality', 'gps_code', 'iata_code', 'local_code', 'wikipedia_link', 'last_updated','landing']].astype('category')
df.dtypes
# Out:
# id                      int64
# ident                category
# type                 category
# name                 category
# latitude_deg          float64
# longitude_deg         float64
# elevation_ft            int64
# continent            category
# iso_country          category
# iso_region           category
# municipality         category
# scheduled_service       int64
# gps_code             category
# iata_code            category
# local_code           category
# home_link               int64
# wikipedia_link       category
# score                   int64
# last_updated         category
# landing              category
# dtype: object

# %%
##Converting category labels into numerical using LabelEncoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(df.ident.drop_duplicates())
df.ident = label.transform(df.ident)
label.fit(df.type.drop_duplicates())
df.type = label.transform(df.type)
label.fit(df.name.drop_duplicates())
df.name = label.transform(df.name)
label.fit(df.continent.drop_duplicates())
df.continent = label.transform(df.continent)
label.fit(df.iso_country.drop_duplicates())
df.iso_country = label.transform(df.iso_country)
label.fit(df.iso_region.drop_duplicates())
df.iso_region = label.transform(df.iso_region)
label.fit(df.municipality.drop_duplicates())
df.municipality = label.transform(df.municipality)
label.fit(df.gps_code.drop_duplicates())
df.gps_code = label.transform(df.gps_code)
label.fit(df.iata_code.drop_duplicates())
df.iata_code = label.transform(df.iata_code)
label.fit(df.local_code.drop_duplicates())
df.local_code = label.transform(df.local_code)
label.fit(df.wikipedia_link.drop_duplicates())
df.wikipedia_link = label.transform(df.wikipedia_link)
label.fit(df.last_updated.drop_duplicates())
df.last_updated = label.transform(df.last_updated)
label.fit(df.landing.drop_duplicates())
df.landing = label.transform(df.landing)
df.dtypes
# Out:
# id                     int64
# ident                  int64
# type                   int64
# name                   int64
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft           int64
# continent              int64
# iso_country            int64
# iso_region             int64
# municipality           int64
# scheduled_service      int64
# gps_code               int64
# iata_code              int64
# local_code             int64
# home_link              int64
# wikipedia_link         int64
# score                  int64
# last_updated           int64
# landing                int64
# dtype: object

# %%
f, ax = plt.subplots(1, 1, figsize=(11, 11))
ax = sns.heatmap(df.corr(), annot=True, cmap='cool')

# %%
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LinearRegression
from sklearn import metrics
x = df.drop(['longitude_deg'], axis = 1)
y = df['longitude_deg']
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)
Lin_reg = LinearRegression()
Lin_reg.fit(x_train, y_train)
print(Lin_reg.intercept_)
print(Lin_reg.coef_)
print(Lin_reg.score(x_test, y_test))
# Out:
# 41.259579989768085
# [ 1.03658032e-06 -9.81104618e-04  2.33190526e-02 -2.41509472e-03
#   8.60953202e-01 -8.26266318e-05 -2.22044605e-15  1.55431223e-15
#   9.46116355e-01  5.40049881e-03  2.72026065e-01  2.63461199e-03
#   5.01574241e-03 -9.34076535e-03  1.11022302e-16  1.51242351e-02
#  -2.49667390e-04 -6.59210911e-03 -4.42809247e-01]
# 0.6762361315071801

# %% [markdown]
# **RANDOM FOREST REGRESSOR:**

# %%
from sklearn.ensemble import RandomForestRegressor as rfr
x = df.drop(['longitude_deg'], axis=1)
y = df.longitude_deg
Rfr = rfr(n_estimators = 100, criterion = 'mse',
                              random_state = 1,
                              n_jobs = -1)
Rfr.fit(x_train,y_train)
x_train_pred = Rfr.predict(x_train)
x_test_pred = Rfr.predict(x_test)

print('MSE train data: %.3f, MSE test data: %.3f' % 
      (metrics.mean_squared_error(x_train_pred, y_train)
      ,metrics.mean_squared_error(x_test_pred, y_test)))
print('R2 train data: %.3f, R2 test data: %.3f' % 
      (metrics.r2_score(y_train,x_train_pred),
       metrics.r2_score(y_test,x_test_pred)))
# Out:
# MSE train data: 0.274, MSE test data: 2.222
# R2 train data: 0.975, R2 test data: 0.795
